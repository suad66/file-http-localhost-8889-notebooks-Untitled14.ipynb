# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd

dataTrain = pd.read_csv(r'C:\Users\Dell\Desktop\laptop_data.csv')

dataTrain.head()
# Out:
#    Inches   TypeName Company ScreenResolution                         Cpu  \
# 0    13.3  Ultrabook   Apple        2560x1600        Intel Core i5 2.3GHz
# 1    13.3  Ultrabook   Apple         1440x900        Intel Core i5 1.8GHz
# 2    15.6   Notebook      HP        1920x1080  Intel Core i5 7200U 2.5GHz
# 3    15.4  Ultrabook   Apple        2880x1800        Intel Core i7 2.7GHz
# 4    13.3  Ultrabook   Apple        2560x1600        Intel Core i5 3.1GHz
#
#    Ram  Memory   Gpu  OpSys  Weight        Price
# 0    8     128   640  macOS    1.37   71378.6832
# 1    8     128  6000  macOS    1.34   47895.5232
# 2    8     256   620  No OS    1.86   30636.0000
# 3   16     512   455  macOS    1.83  135195.3360
# 4    8     256   650  macOS    1.37   96095.8080

# %%
type(dataTrain)
# Out:
# pandas.core.frame.DataFrame

# %%
dataTrain.shape
# Out:
# (1303, 11)

# %%
dataTrain.dtypes
# Out:
# Inches              float64
# TypeName             object
# Company              object
# ScreenResolution     object
# Cpu                  object
# Ram                   int64
# Memory                int64
# Gpu                   int64
# OpSys                object
# Weight              float64
# Price               float64
# dtype: object

# %%
dataTrain = dataTrain.dropna()

# %%
dataTrain.isnull().sum()
# Out:
# Inches              0
# TypeName            0
# Company             0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
dataTrain.shape
# Out:
# (1303, 11)

# %%
 dataTrain.describe()
# Out:
#             Inches          Ram       Memory          Gpu       Weight  \
# count  1303.000000  1303.000000  1303.000000  1303.000000  1303.000000
# mean     15.009056     8.382195   226.215656   695.855718     2.038734
# std       1.452957     5.084665   174.438239   546.915086     0.665475
# min       5.000000     2.000000     1.000000     0.000000     0.690000
# 25%      14.000000     4.000000    64.000000   520.000000     1.500000
# 50%      15.600000     8.000000   256.000000   620.000000     2.040000
# 75%      15.600000     8.000000   256.000000   930.000000     2.300000
# max      18.400000    64.000000   517.000000  6150.000000     4.700000
#
#                Price
# count    1303.000000
# mean    59870.042910
# std     37243.201786
# min      9270.720000
# 25%     31914.720000
# 50%     52054.560000
# 75%     79274.246400
# max    324954.720000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
corr = dataTrain.corr()

sns.heatmap(corr,annot=True)
plt.show()

# %%
dataTrain.describe()
# Out:
#             Inches          Ram       Memory          Gpu       Weight  \
# count  1303.000000  1303.000000  1303.000000  1303.000000  1303.000000
# mean     15.009056     8.382195   226.215656   695.855718     2.038734
# std       1.452957     5.084665   174.438239   546.915086     0.665475
# min       5.000000     2.000000     1.000000     0.000000     0.690000
# 25%      14.000000     4.000000    64.000000   520.000000     1.500000
# 50%      15.600000     8.000000   256.000000   620.000000     2.040000
# 75%      15.600000     8.000000   256.000000   930.000000     2.300000
# max      18.400000    64.000000   517.000000  6150.000000     4.700000
#
#                Price
# count    1303.000000
# mean    59870.042910
# std     37243.201786
# min      9270.720000
# 25%     31914.720000
# 50%     52054.560000
# 75%     79274.246400
# max    324954.720000

# %%
dataTrain.loc[dataTrain['Price'] == 1, 'Price'] = 1000

# %%
dataTrain.describe()
# Out:
#             Inches          Ram       Memory          Gpu       Weight  \
# count  1303.000000  1303.000000  1303.000000  1303.000000  1303.000000
# mean     15.009056     8.382195   226.215656   695.855718     2.038734
# std       1.452957     5.084665   174.438239   546.915086     0.665475
# min       5.000000     2.000000     1.000000     0.000000     0.690000
# 25%      14.000000     4.000000    64.000000   520.000000     1.500000
# 50%      15.600000     8.000000   256.000000   620.000000     2.040000
# 75%      15.600000     8.000000   256.000000   930.000000     2.300000
# max      18.400000    64.000000   517.000000  6150.000000     4.700000
#
#                Price
# count    1303.000000
# mean    59870.042910
# std     37243.201786
# min      9270.720000
# 25%     31914.720000
# 50%     52054.560000
# 75%     79274.246400
# max    324954.720000

# %%
import matplotlib.pyplot as plt

dataTrain['Price'].plot(kind = 'hist', bins = 5, edgecolor='black')   # 5 bins are used
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of Prices')
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.regplot(x="Inches", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
dataTrain.describe(include = 'object') #summary statistics for categorical values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 dataTrain.describe(include = 'object')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11552, in NDFrame.describe(self, percentiles, include, exclude)
#   11310 @final
#   11311 def describe(
#   11312     self,
#    (...)
#   11315     exclude=None,
#   11316 ) -> Self:
#   11317     """
#   11318     Generate descriptive statistics.
#   11319
#    (...)
#   11550     max            NaN      3.0
#   11551     """
# > 11552     return describe_ndframe(
#   11553         obj=self,
#   11554         include=include,
#   11555         exclude=exclude,
#   11556         percentiles=percentiles,
#   11557     ).__finalize__(self, method="describe")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\methods\describe.py:97, in describe_ndframe(obj, include, exclude, percentiles)
# ...

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.regplot(x="Ram", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(dataTrain['Ram'], dataTrain['Price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.743007135250695  with a P-value of P = 3.9103435619843916e-229

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="Memory", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Memory', ylabel='Price'>

# %%
pearson_coef, p_value = stats.pearsonr(dataTrain['Memory'], dataTrain['Price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.2966008010776523  with a P-value of P = 7.152552722783012e-28

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="Weight", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
pearson_coef, p_value = stats.pearsonr(dataTrain['Weight'], dataTrain['Price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.21036979891687177  with a P-value of P = 1.687222341888722e-14

# %%
sns.boxplot(x="TypeName", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='TypeName', ylabel='Price'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="OpSys", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='OpSys', ylabel='Price'>

# %%
sns.boxplot(x="Gpu", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Gpu', ylabel='Price'>

# %%
sns.boxplot(x="Cpu", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Cpu', ylabel='Price'>

# %%
sns.boxplot(x="ScreenResolution", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='ScreenResolution', ylabel='Price'>

# %%
sns.boxplot(x="Company", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Company', ylabel='Price'>

# %%
sns.boxplot(x="TypeName", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='TypeName', ylabel='Price'>

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()
dataTrain.Inches = labelencoder.fit_transform(dataTrain.Inches)
dataTrain.ScreenResolution = labelencoder.fit_transform(dataTrain.ScreenResolution)
dataTrain.Ram = labelencoder.fit_transform(dataTrain.Ram)
dataTrain.Memory = labelencoder.fit_transform(dataTrain.Memory)

dataTrain.Gpu = labelencoder.fit_transform(dataTrain.Gpu)
dataTrain.Weight = labelencoder.fit_transform(dataTrain.Weight)

# %%
dataTrain.head(10)
# Out:
#      Inches  TypeName   Company  ScreenResolution       Cpu       Ram  \
# 0 -1.362940  1.138779 -1.333189          0.634655 -0.475914  0.183436
# 1 -1.362940  1.138779 -1.333189          1.269310 -0.555339  0.183436
# 2  0.557557  0.335406  0.136477          1.523172 -0.118498  0.183436
# 3  0.283200  1.138779 -1.333189          0.761586  0.318342  1.549245
# 4 -1.362940  1.138779 -1.333189          0.634655 -0.396488  0.183436
# 5  0.557557  0.335406 -1.578133          1.142379 -2.501266 -1.182374
# 6  0.283200  1.138779 -1.333189          1.903965  0.278630  1.549245
# 7 -1.362940  1.138779 -1.333189          1.269310 -0.555339  0.183436
# 8 -0.539870  1.138779 -1.088245          0.126931  1.152311  1.549245
# 9 -0.539870  1.138779 -1.578133          0.126931  0.238917  0.183436
#
#      Memory       Gpu     OpSys    Weight     Price
# 0 -0.229199  0.390826  3.083616 -1.143311  0.309132
# 1 -0.229199  2.109144  3.083616 -1.218146 -0.321646
# ...

# %%
import scipy.stats as stats
dataTrain = stats.zscore(dataTrain)

# %%
x_train.head()
# Out:
#      Inches  TypeName   Company  ScreenResolution       Cpu       Ram  \
# 0 -1.362940  1.138779 -1.333189          0.634655 -0.475914  0.183436
# 1 -1.362940  1.138779 -1.333189          1.269310 -0.555339  0.183436
# 2  0.557557  0.335406  0.136477          1.523172 -0.118498  0.183436
# 3  0.283200  1.138779 -1.333189          0.761586  0.318342  1.549245
# 4 -1.362940  1.138779 -1.333189          0.634655 -0.396488  0.183436
#
#      Memory       Gpu     OpSys    Weight     Price
# 0 -0.229199  0.390826  3.083616 -1.143311  0.309132
# 1 -0.229199  2.109144  3.083616 -1.218146 -0.321646
# 2  0.529428  0.234616 -0.781657 -0.270240 -0.785251
# 3  1.288054 -0.936964  3.083616 -0.345074  2.023301
# 4  0.529428  0.468932  3.083616 -1.143311  0.973055

# %%
dataTrain.drop(['Inches', 'TypeName', 'Cpu'], axis = 1, inplace = True)

# %%
dataTrain.shape
# Out:
# (1303, 5)

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()
dataTrain.Company= labelencoder.fit_transform(dataTrain.Company)
dataTrain.ScreenResolution = labelencoder.fit_transform(dataTrain.ScreenResolution)
dataTrain.Ram = labelencoder.fit_transform(dataTrain.Ram)
dataTrain.Memory = labelencoder.fit_transform(dataTrain.Memory)

dataTrain.Gpu = labelencoder.fit_transform(dataTrain.Gpu)
dataTrain.Weight = labelencoder.fit_transform(dataTrain.Weight)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1612\846430031.py in ?()
#       2
#       3 labelencoder = LabelEncoder()
#       4 dataTrain.Company= labelencoder.fit_transform(dataTrain.Company)
#       5
# ----> 6 dataTrain.Ram = labelencoder.fit_transform(dataTrain.Ram)
#       7 dataTrain.Memory = labelencoder.fit_transform(dataTrain.Memory)
#       8
#       9 dataTrain.Gpu = labelencoder.fit_transform(dataTrain.Gpu)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Ram'

# %%
dataTrain.head(10)
# Out:
#    Company    Memory     OpSys    Weight     Price
# 0        1 -0.229199  3.083616 -1.143311  0.309132
# 1        1 -0.229199  3.083616 -1.218146 -0.321646
# 2        7  0.529428 -0.781657 -0.270240 -0.785251
# 3        1  1.288054  3.083616 -0.345074  2.023301
# 4        1  0.529428  3.083616 -1.143311  0.973055
# 5        0  0.782303  0.184661  0.253603 -1.035702
# 6        1  0.529428 -1.747976  0.103934  1.454449
# 7        1  0.529428  3.083616 -1.218146  0.050109
# 8        2  1.288054  0.184661 -1.292981  0.531403
# 9        0  0.529428  0.184661 -0.694303 -0.506178

# %%
import scipy.stats as stats
dataTrain = stats.zscore(dataTrain)

# %%
dataTrain.shape
# Out:
# (1303, 5)

# %%
dataTrain
# Out:
#        Company    Memory     OpSys    Weight     Price
# 0    -1.333189 -0.229199  3.083616 -1.143311  0.309132
# 1    -1.333189 -0.229199  3.083616 -1.218146 -0.321646
# 2     0.136477  0.529428 -0.781657 -0.270240 -0.785251
# 3    -1.333189  1.288054  3.083616 -0.345074  2.023301
# 4    -1.333189  0.529428  3.083616 -1.143311  0.973055
# ...        ...       ...       ...       ...       ...
# 1298  0.871310 -0.229199  0.184661 -0.370019 -0.695089
# 1299  0.871310  1.288054  0.184661 -1.292981  0.537128
# 1300  0.871310 -0.482074  0.184661 -0.843973 -1.280428
# 1301  0.136477 -1.746451  0.184661  0.428218 -0.514765
# 1302 -1.088245  0.782303  0.184661  0.478108 -1.080067
#
# [1303 rows x 5 columns]

# %%
x_train=dataTrain.iloc[:,0:11]
y_train=dataTrain.iloc[:,12]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[160], line 2
#       1 x_train=dataTrain.iloc[:,0:11]
# ----> 2 y_train=dataTrain.iloc[:,12]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1652, in _iLocIndexer._getitem_tuple(self, tup)
#    1651 def _getitem_tuple(self, tup: tuple):
# -> 1652     tup = self._validate_tuple_indexer(tup)
#    1653     with suppress(IndexingError):
#    1654         return self._getitem_lowerdim(tup)
#
# ...

# %%
x_train.head()
# Out:
#     Company    Memory     OpSys    Weight     Price
# 0 -1.333189 -0.229199  3.083616 -1.143311  0.309132
# 1 -1.333189 -0.229199  3.083616 -1.218146 -0.321646
# 2  0.136477  0.529428 -0.781657 -0.270240 -0.785251
# 3 -1.333189  1.288054  3.083616 -0.345074  2.023301
# 4 -1.333189  0.529428  3.083616 -1.143311  0.973055

# %%
y_train.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[162], line 1
# ----> 1 y_train.head()
#
# NameError: name 'y_train' is not defined

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model_mlr = model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[163], line 4
#       1 from sklearn.linear_model import LinearRegression
#       3 model = LinearRegression()
# ----> 4 model_mlr = model.fit(x_train,y_train)
#
# NameError: name 'y_train' is not defined

# %%
rf = RandomForestRegressor()
model_rf = rf.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[164], line 2
#       1 rf = RandomForestRegressor()
# ----> 2 model_rf = rf.fit(x_train,y_train)
#
# NameError: name 'y_train' is not defined

# %%
LassoModel = Lasso()
model_lm = LassoModel.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[165], line 2
#       1 LassoModel = Lasso()
# ----> 2 model_lm = LassoModel.fit(x_train,y_train)
#
# NameError: name 'y_train' is not defined

# %%
mae = pd.DataFrame(data = scores, columns=['Model', 'MAE Score'])
mae
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[166], line 1
# ----> 1 mae = pd.DataFrame(data = scores, columns=['Model', 'MAE Score'])
#       2 mae
#
# NameError: name 'scores' is not defined
